# %% [markdown]
# # SYD DAT 8 Lab 1 - Git and Markdown
#
# ## Homework:
#
# #### Setup
# * Resolve any installation issues before next class.
# * Make sure you have a github profile and created a repo called "SYD_DAT_8"
# <font color = red> GP - Repo is called DAT8SYD </font>
# * Clone the class repo (this one!)
# * Review this [code](../labs/Week 1/00_python_refresher.py) for a recap of some Python basics.
#
# #### Communication
# * Read [Analyzing the Analyzers](http://cdn.oreillystatic.com/oreilly/radarreport/0636920029014/Analyzing_the_Analyzers.pdf) for a useful look at the different types of data scientists. Write down 5 key points you took away from the article
# * Read about some [Markdown Techniques](http://daringfireball.net/projects/markdown/syntax)
# * Write a summary of 2 chapters of [The Data Science Handbook](http://www.thedatasciencehandbook.com/) in Markdown in this notebook and commit it to your repository on github
#
# #### Programming
# * Complete the lab from class and the additional Exercise below
#
# #### Course Project
# * Come up with 5 different ideas for your course project. For each one list:
#   * Overview of your idea
#   * What data you will use
#   * What the outcome is that you are trying to achieve
#   * Any ideas of modelling techniques it may involve
#
# **Instructions: copy this file and append your name in the filename, e.g. Homework1_ian_hansel.ipynb.
# Then commit this in your local repository, push it to your github account so I can see your work. Remeber if you get stuck to look at the slides going over Git**

# %% [markdown]
# # Communication
# ## Analyzing the Analyzers Reading
# #### Short Summary
# * Harris, Murphy, Vaisman 2012; article and write up of a survey conducted on the DC "analytics/data science/big data/applied stats/Machine Learning" community with 250 respondants.
# * The problem this article and study was trying to address was the waste of time and resources in the industry due to a poor understanding of the diversity and skills within the workforce (i.e. attempting to hire a single developer to perform a "Rockstar/God" remit of work).
# * Respondants were asked to describe their background, skills and how they self identified. These results were submitted to "cluster analysis", to identify 4 skill and ID groupings, titled "Data Businesspeople", "Data Creatives", "Data Developer", and "Data Researchers".
#
# #### Key Takeaways
# 1. The study is problematic. <br>
#     *Sample size was low, storytelling got in the way of the results, and absence of parameters like "Number of years in field" along with focus on viral/social link sharing skewed the results.*
# 2. Mosaic charts are money! <br>
#     *Colors are much more nicer than a stacked column with a legend!*
# 3. The categories aren't bad ones to act on, and quick classification can be achieved using the T-skill model. <br>
#     *Can qualify a Data Business Person from a Data Researcher by asking whether their depth of skill is Biz vs Stats*
# 4. Huge datasets were uncommon across all skillsets, supporting DS as a seperate and unique discipline to Big Data. <br>
#     *Though has this changed in the 5 years since 2012?*
# 5. Qualify your hiring managers. <br>
#     *Candidates must protect themselves from "Rockstar/God" or "apples vs oranges" expectations.
#
#
# ## Data Scientist Handbook 2 Chapter Summary
# > Selected chapters are:
# > * <font color=red> Michael Hochster, LinkedIN, "The Importance of Developing Data Sense" </font> <br>
# > * <font color=blue> Diane Wu, Palantir/MetaMind, "The Interplay between Science, Engineering and Data Science". </font>
#
# #### <font color=red> Michael Hochster </font>
# I chose this chapter due to the promised discussion of **data sense** - something I've built an appreciation of when being exposed to unfamiliar data sets at the Minerva Collective.
# Michael's thoughts on this mysterious quality came towards the end - and referenced Skomoroch's definition of Data Scientists into Type 1 and Type 2 (which I understand was used to build teams at LinkedIn). The reason you can't call a Type 1 "Data Scientist" a "Statistician" is because there is more to handling and wrangling data than most statisticians are ready to tackle. Data sense broke down to a way of thinking about a dataset that answers the following questions:
# * What should I compare?
# * Whats the control?
# * How can I transform it to make it more reasonable?
# * What do I need to go away and find/measure?
# As for how to get it - Hochster cites a diverse and deep experience with data, but it essentially seems to be a knack. Darn.
# Thankfully, there was a more concrete payoff in the discussion of "Metrics" and how it's difficult to design and evaluate metrics (i.e. there's no metrics for metrics". His method involves:
# * Coming up with something plausable (i.e. clicks vs percieved value of result)
# * Think up circumstances where it would point in the opposite direction.
# * Identify cases of these circumstances.
# * Impose segmentation to avoid these circumstances/noise.
#
# #### <font color=blue> Diane Wu </font>
# I chose this chapter due to my familiarity with Metamind, and Diane's academic background.
# Her chapter discussed the following concepts:
# 1. Data science has an umbrella definition, and a lot of roles have difficulty defining success (i.e. not everybody can entirely measure success on the accuracy of their predicted models).
# 2. The T-shape model for skills and specialization, where one should have lots of breadth and find the one area to add more depth.
# 3. Her Data science process, where she
#     * identifies an Actionable goal or desired insight. <br>
#     * Evaluates the Form, scale, reliability, availability of data
#     * Builds the ML algorithms.
#     * Iterate.
# 4. How computers and humans can form a **symbiosis**, where **computers** crunch the models, and **humans** interpret the patterns to make accountable decisions.
#
# The key concept involved the balance of scientific and engineering mentality. Almost always, with real world problems, there is no time to ask why and figure everything out before executing, and you often have to act with incomplete knowledge. As such, a candidate needs to be able to think like an engineer. However, engineering without data science is like building a bridge without ever fail testing it. There is a delicate balance to be struck.

# %% [markdown]
# # Programming

# %% [markdown]
# ## Exercise Four - Movie Lens Data

# %%
# TASKS:
# for each occupation in 'users', count the number of occurrences

# for each occupation, calculate the mean age

# for each occupation, calculate the minimum and maximum ages

# for each combination of occupation and gender, calculate the mean age

# randomly sample a DataFrame

# detect duplicate users

# %% [markdown]
# #### For each occupation in 'users', count the number of occurrences

# %%
'''
Setup
'''
import numpy as np
import pandas as pd
import os

# %pwd
# Out:
# '/Users/sfdcapacmarketing/Documents/DataScience Copy/Cloned Repository/DAT8SYD/homework'

# %%
'''
Import and setup column names
'''
unames = ['user_id', 'age', 'gender', 'occupation', 'zip']
users = pd.read_table('/Users/sfdcapacmarketing/Documents/DataScience Copy/Cloned Repository/DAT8SYD/data/u.user', sep = '|', header=None, names=unames, dtype={'zip':str})
users.head()
# Out:
#    user_id  age gender  occupation    zip
# 0        1   24      M  technician  85711
# 1        2   53      F       other  94043
# 2        3   23      M      writer  32067
# 3        4   24      M  technician  43537
# 4        5   33      F       other  15213

# %%
'''Count occupation using pandas method'''
users.occupation.value_counts()
# Out:
# student          196
# other            105
# educator          95
# administrator     79
# engineer          67
# programmer        66
# librarian         51
# writer            45
# executive         32
# scientist         31
# artist            28
# technician        27
# marketing         26
# entertainment     18
# healthcare        16
# retired           14
# lawyer            12
# salesman          12
# none               9
# doctor             7
# homemaker          7
# Name: occupation, dtype: int64

# %% [markdown]
# #### For each occupation, calculate the mean age

# %%
users[['occupation','age']].groupby('occupation').mean().sort_values(by='age',ascending=False)
# Out:
#                      age
# occupation
# retired        63.071429
# doctor         43.571429
# educator       42.010526
# healthcare     41.562500
# librarian      40.000000
# administrator  38.746835
# executive      38.718750
# marketing      37.615385
# lawyer         36.750000
# engineer       36.388060
# writer         36.311111
# salesman       35.666667
# scientist      35.548387
# other          34.523810
# technician     33.148148
# programmer     33.121212
# homemaker      32.571429
# artist         31.392857
# entertainment  29.222222
# none           26.555556
# student        22.081633

# %% [markdown]
# #### For each occupation, calculate the minimum and maximum ages

# %%
# ages = users[['occupation','age']].groupby('occupation').min()
ages = users[['occupation','age']].groupby('occupation').min()
ages.columns = ['Minage']
ages['Maxage']=users[['occupation','age']].groupby('occupation').max()
ages['Delta']=users[['occupation','age']].groupby('occupation').max() - users[['occupation','age']].groupby('occupation').min()
print(ages.sort_values(by='Delta',ascending=False))
# Out:
#                Minage  Maxage  Delta
# occupation
# other              13      64     51
# administrator      21      70     49
# salesman           18      66     48
# engineer           22      70     48
# executive          22      69     47
# librarian          23      69     46
# none               11      55     44
# programmer         20      63     43
# writer             18      60     42
# healthcare         22      62     40
# educator           23      63     40
# doctor             28      64     36
# entertainment      15      50     35
# student             7      42     35
# technician         21      55     34
# lawyer             21      53     32
# scientist          23      55     32
# marketing          24      55     31
# homemaker          20      50     30
# artist             19      48     29
# retired            51      73     22

# %% [markdown]
# #### For each combination of occupation and gender, calculate the mean age

# %%
agesoccu=users[['occupation','gender','age']].groupby(['occupation','gender']).mean()
agesoccu.columns = ['Mean Age']
agesoccu
# No missing doctors!
# agesoccu.sort_values(by='Mean Age',ascending=False)
# Out:
#                        Mean Age
# occupation    gender
# administrator F       40.638889
#               M       37.162791
# artist        F       30.307692
#               M       32.333333
# doctor        M       43.571429
# educator      F       39.115385
#               M       43.101449
# engineer      F       29.500000
#               M       36.600000
# entertainment F       31.000000
#               M       29.000000
# executive     F       44.000000
#               M       38.172414
# healthcare    F       39.818182
#               M       45.400000
# homemaker     F       34.166667
#               M       23.000000
# lawyer        F       39.500000
#               M       36.200000
# librarian     F       40.000000
#               M       40.000000
# marketing     F       37.200000
#               M       37.875000
# none          F       36.500000
#               M       18.600000
# other         F       35.472222
#               M       34.028986
# ...

# %% [markdown]
# #### Randomly sample a DataFrame

# %%
# Sorting rows into 1 of 2 groups - 

# set a random seed for reproducibility
np.random.seed(54321)

# assign random values to each row
users['Rand'] = np.random.randint(1, 3, len(users))

# assign rows to samples based on random integer value
sample1 = users[(users['Rand'] == 1)]
sample2 = users[(users['Rand'] == 2)]
print(len(sample1),len(sample2))
# Out:
# 474 469

# %% [markdown]
# #### Detect duplicate users

# %%
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.duplicated.html

# ********
# candidates are user_id, or combination of age, gender, occupation, zip

# users['Dup']=users.duplicated(subset='user_id',keep=False) # Outcome is zero true rows
# users['Dup']=users.duplicated(subset='user_id',keep=False)
users['Check']=users.age.map(str)+users.gender+users.occupation+users.zip
users['Dup']=users.duplicated(subset='Check',keep='first')
# users.head() 

# ********
# Dup Detection
users[users.Dup == True]

# ********
# OPTIONAL - Export for Manual Detection and validation
# users.to_csv('users_saved.csv')
# Out:
#      user_id  age gender occupation    zip  Rand   Dup             Check
# 495      496   21      F    student  55414     2  True   21Fstudent55414
# 571      572   51      M   educator  20003     1  True  51Meducator20003
# 620      621   17      M    student  60402     2  True   17Mstudent60402
# 683      684   28      M    student  55414     2  True   28Mstudent55414
# 732      733   44      F      other  60630     1  True     44Fother60630
# 804      805   27      F      other  20009     2  True     27Fother20009
# 889      890   32      M    student  97301     1  True   32Mstudent97301

# %% [markdown]
# # Programming

# %% [markdown]
# >* Come up with 5 different ideas for your course project. For each one list:
# >  * Overview of your idea
# >  * What data you will use
# >  * What the outcome is that you are trying to achieve
# >  * Any ideas of modelling techniques it may involve

# %% [markdown]
# **Question** | **Idea 1** | **Idea 2** | **Idea 3** | **Idea 4** | **Idea 5**
# -------- | ------ | ------ | ------ | ------ | ------
# **Overview of your idea** | Is traditional lead scoring a good predictor for event oppty gen? | What segments are present in engagement data, and how do they compare to our communications segments? | Will a Holliwood remake deliver a greater return than the original? | Can the Australian Census predict Charitable Giving? | Can social sentiment data predict market swings in Ethereum?
# **What data you will use** | Single table - delegates tagged with lead score and opportunity generated, along with a number of other features | delegate table and time series engagement data table | IMDB Data, and potentially some other budget/movie projects data | ACNC reports, their precursor, and the June 2017 census data! | Coinbase market data and twitter data, via API
# **What outcomes are trying to be achieved** | Better lead conversion rate - more pipe gen | Better customer experience; new ways of communicating with attendees | Mirth | Fundraising strategy in charities | All the dollars
# **What modelling techniques will get involved** | Classification, and potentially some regression | Clustering | Classification | Classification | Classification
